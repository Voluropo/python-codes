# %%
def intro():
    print('Welcome to Chef Victor\s Kitchen')
    print('We have the best quality food and cheap and affordable prices')
    print('We hope you enjoy your stay')
    print('And come back again Thank You')

def main():
    intro()
    tag = int(input('Please choose a tag:'))
    if tag == 1:
        plate = int(input(' you have chosen rice stuffs How many plates would you like:'))
        rice = int(input('Portions of rice:'))
        water = int(input('How many bottles of water:'))
        chicken = int(input('How many portions of chicken:'))
        drink = int(input('how many drinks:'))
        plantain = int(input('how many portions of plantain:'))
        salad = int(input('how much salad:'))
  #calculations

        rice_total = rice*500
        water_total = water*200
        chicken_total = chicken*1200
        drink_total = drink*300
        salad_total = salad*700
        plantain_total = plantain*300
        
        total_price = plate*(rice_total+water_total+chicken_total+drink_total+salad_total+plantain_total)
        
        print(f'Find above your order and total price is {total_price}')
        print('Thanks for visiting')
        feedback = input('Please give us a rating and feedback')
        
    elif tag == 2:
        plate = int(input('you have chosen swallows How many plates would you like:'))
        chicken = int(input('How much chicken:'))
        swallow = int(input('Numbers of swallow:'))
        goat_head = int(input('How many goat head:'))
        cow_head = int(input('How many cow head:'))
        beef = int(input('How many pieces of beef:'))
        drink = int(input('how many drinks:'))
        water = int(input('How many bottles of water:'))
  #calculations
        swallow_total = swallow*500
        cow_head_total = cow_head*1000
        beef_total = beef*800
        goat_head_total = goat_head*700
        drink_total = drink*300
        water_total = water*200
        
        
        total_price = plate*(swallow_total+cow_head_total+beef_total+goat_head_total+drink_total+water_total)
        
        print(f'Find above your order and total price is {total_price}')
        print('Thanks for visiting')
        feedback = input('Please give us a rating and feedback')
         
    elif tag == 3:
        plate = int(input('You have chosen Patries How many plates would you like:'))
        meat_pie = int(input('How many meatpie:'))
        shawarma = int(input('Numbers of sharwarma:'))
        chicken_and_chips = int(input('How many chicken and chips:'))
        burger = int(input('How many burger: '))
        cake = int(input('How many cakes:'))
       
  #calculations
        meat_pie_total = meat_pie*450
        shawarma_total = shawarma*1500
        chicken_and_chips_total = chicken_and_chips*2500
        burger_total = burger*700
        cake_total = cake*1500
        
        total_price = plate*(meat_pie_total+shawarma_total+chicken_and_chips_total+burger_total+cake_total)
        print(f'Find above your order and total price is {total_price}')
        print('Thanks for visiting')
        feedback = input('Please give us a rating and feedback')
    else:
        print('invalid tag')
main()
