# %%
record1 = ('JRN')
record2 = ('ITM')
record3 = ('SRN')
import random
import math
staffnumbers = [record1,record2,record3]
count = 1
while count <= 1000:
    num = random.randint(100,5000)
    staffnumbers.append(num)
    count += 1
u_staffnumber = list(map(lambda records: (records),staffnumbers))
print(u_staffnumber)
# Out:
# ['JRN', 'ITM', 'SRN', 3177, 1659, 4604, 180, 723, 3443, 1320, 2082, 214, 3373, 3506, 1523, 2292, 4047, 3958, 2034, 3201, 1919, 3761, 3625, 4270, 1828, 389, 2497, 3343, 4494, 3941, 1930, 3751, 3116, 2220, 1350, 495, 2043, 2081, 1831, 1099, 3255, 2709, 2335, 718, 1577, 4492, 4245, 4854, 3839, 1354, 2568, 463, 2843, 1177, 4374, 2402, 762, 3456, 2494, 3454, 4608, 3532, 1476, 4430, 523, 3753, 538, 1248, 3122, 1137, 4469, 1304, 1257, 1944, 1546, 380, 4399, 4940, 4714, 2735, 2961, 3210, 1061, 862, 1597, 1349, 4922, 1497, 454, 698, 2948, 2200, 3530, 3748, 2259, 1466, 1019, 2740, 4941, 4413, 4622, 4545, 683, 3788, 4530, 520, 3118, 4080, 1209, 2636, 3510, 3531, 2047, 593, 2494, 471, 2776, 282, 1647, 891, 4179, 3596, 1359, 567, 4374, 4454, 3603, 4649, 964, 1985, 2097, 3826, 4602, 4049, 881, 2617, 3525, 4488, 1077, 4776, 3372, 1430, 425, 265, 1041, 866, 633, 931, 2657, 4564, 1807, 2208, 753, 3665, 2834, 833, 4917, 3222, 2720, 289, 708, 2704, 1878, 1289, 1945, 2814, 3037, 743, 1673, 4764, 3026, 2
# ...

# %%
u_staff = list(filter(lambda u_staff: staffnumbers,record3))
print(u_staff)
# Out:
# ['S', 'R', 'N']

# %%
import random
import math
numbers = []
count = 1
while count <= 35:
    num = random.randint(45,70)
    numbers.append(num)
    count += 1
u_numbers = list(map(lambda digit: math.sqrt(digit),numbers))
print(u_numbers)
